# %% [raw]
# In this notebook we are testing the functioning of pro-moca

# %%
from promoca.PRO_MOCA import *

# %load_ext autoreload
# %autoreload 2

# %%
df_motifs_CLUMPs_path = 'df_motifs_CLUMPs_standard_scaling.tsv'

# %%
help(pro_moca)
# Out:
# Help on function pro_moca in module promoca.PRO_MOCA:
#
# pro_moca(df_motifs_CLUMPs_path, classification_scheme)
#     pro_moca
#     --------
#     PRO-MOCA (PROtein-MOtif Characteristics Aligner) is an
#     aligner of motif sequences.
#     PRO-MOCA aligns short sequences based on the characteristics
#     of the AAs rather than the AAs themselves.
#
#     The algorithm doesn't employ a substitution matrix.
#     Instead, PRO-MOCA employes a classification scheme of the
#     AAs to convert the motifs into patterns of letters. Then
#     looks for a central position of the patterns, where a
#     certain letter is repeated more than in the others.
#     Based on the central position of the alignment, it then
#     calculates the number of gaps ('_') to add to the right and
#     to the left of all the patterns, after centering them.
#     At the end it reconverts the patterns into motifs,
#     and gives a list of motifs with gaps to the left and
#     to the right.
#
# ...

# %% [markdown]
# # chemical alignment

# %%
dict_alignments_all_lsts_motifs = pro_moca(df_motifs_CLUMPs_path, 'che')
# Out:
# folder exists
# chemical classification scheme chosen
#
#  the following are the classes of AAs:
#  polar -> P
#  hydrophobic -> H
#  neutral -> N
#  acid -> A
#  basic -> B
#
#
#
#
#
# /\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
# ------------------------------------------
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\
#
#
#
# This is the alignment for CLUMP 0
#
#
#
# original lst_patterns ['PBHP', 'PBHPN', 'BHP', 'BHPN', 'HHP', 'HNP', 'PPBP', 'PNP', 'HPHH', 'HPH', 'NHP', 'HNP', 'HPNP', 'BHH']
#
#
#
#
#  -----------------
#  -----------------
#  letter_for_position H
#
#
#  lst_pos ['_', '_', '_', '_', 'H', 'H', '_', '_', 'H', 'H', '_', 'H', 'H', '_']
#
#  lst_indexes_letter_for_position [4, 5, 8, 9, 11, 12]
#
#
#
#  -----------------
#  letter_for_position P
#
#
#  lst_pos ['P', 'P', '_', '_', '_', '_', 'P', 'P', 'P', 'P', '_', '_', 'P', '_']
#
#  lst_indexes_letter_for_position [0, 1, 6, 7, 8, 9, 12]
#
#
#
#  -----------------
#  letter_for_position ['B', 'N']
#
#
# ...

# %%
dict_alignments_all_lsts_motifs
# Out:
# {0: ['_GHWT_',
#   '_GHWTQ',
#   '__HWT_',
#   '__HWTQ',
#   '__WWS_',
#   '_WNT__',
#   '__YSHS',
#   '_CQY__',
#   '_FSVF_',
#   '_FSL__',
#   '__NVY_',
#   '_WNS__',
#   'FTNS__',
#   '__HWF_'],
#  1: ['PGNV_',
#   'PTHP_',
#   'YPSG_',
#   'PYPGQ',
#   'PYPSG',
#   'GYPSG',
#   'RYPSG',
#   'LYPSG',
#   'PKPF_',
#   'PTPK_',
#   'YYPGG',
#   'PKPY_',
#   'VYPSG',
#   'PSPK_',
#   'PYQSG',
#   'PKPN_',
#   'PPPK_',
#   'KPPG_',
#   'RGIG_',
#   'FPSP_',
#   'KYPN_',
#   'NGQP_'],
#  2: ['PKPK_',
#   'PKYK_',
#   'WKPK_',
#   '_KHP_',
#   '_KYKS',
#   '_KQAQ',
#   '_KTKL',
#   'PKAK_',
#   '_QEAF',
#   '_HGD_',
#   'AYKN_',
#   '_KMKG',
#   'FKAK_',
#   'IKNN_',
#   '_KKIS',
#   'MDKF_',
#   'VKSY_'],
#  3: ['ADAE_',
#   'CGEGE',
#   'DAP__',
#   'ACGE_',
#   'ATEN_',
#   'DQAG_',
#   'KDLE_',
#   'MGVE_',
#   'QEKL_',
#   'SNEE_',
#   'AEG__',
#   'AEAD_',
#   'AETD_',
#   'DENL_',
#   'NEAK_',
#   'NEPL_',
#   'TEAK_',
#   'VDEG_'],
#  4: ['TQLA',
#   'NLVG',
#   'AYAR',
# ...

# %%
for CLUMP, alignment in dict_alignments_all_lsts_motifs.items():
    print(CLUMP)
    print('\n')
    for motif in alignment:
        print(motif)
    print('\n')
    print('----------')
# Out:
# 0
#
#
# _GHWT_
# _GHWTQ
# __HWT_
# __HWTQ
# __WWS_
# _WNT__
# __YSHS
# _CQY__
# _FSVF_
# _FSL__
# __NVY_
# _WNS__
# FTNS__
# __HWF_
#
#
# ----------
# 1
#
#
# PGNV_
# PTHP_
# YPSG_
# PYPGQ
# PYPSG
# GYPSG
# RYPSG
# LYPSG
# PKPF_
# PTPK_
# YYPGG
# PKPY_
# VYPSG
# PSPK_
# PYQSG
# PKPN_
# PPPK_
# KPPG_
# RGIG_
# FPSP_
# KYPN_
# NGQP_
#
#
# ----------
# 2
#
#
# PKPK_
# PKYK_
# WKPK_
# _KHP_
# _KYKS
# _KQAQ
# _KTKL
# PKAK_
# _QEAF
# _HGD_
# AYKN_
# _KMKG
# FKAK_
# IKNN_
# _KKIS
# MDKF_
# VKSY_
#
#
# ----------
# 3
#
#
# ADAE_
# CGEGE
# DAP__
# ACGE_
# ATEN_
# DQAG_
# KDLE_
# MGVE_
# QEKL_
# SNEE_
# AEG__
# AEAD_
# AETD_
# DENL_
# NEAK_
# NEPL_
# TEAK_
# VDEG_
#
#
# ----------
# 4
#
#
# TQLA
# NLVG
# AYAR
# DIAK
# NLTL
# QLAK
# AAIE
# ILDN
# RNLL
# MIE_
# IANG
# ILAN
# QVAS
# TILG
# TML_
# VEAV
# VHAA
#
#
# ----------
# 5
#
#
# CGIGG
# CGCCG
# CGIGR
# CGNCG
# CGSGG
# CCCGG
# CGDGF
# CGGGF
# CNICG
# CGGGY
# CCCGF
# CNGGG
# CGCCA
# CGDSG
# CQNGG
# CGGGA
# CGKAG
# CCSGY
# PNPGG
# PSPGG
# ...

# %% [markdown]
# # hydrophobicity alignment

# %%
dict_alignments_all_lsts_motifs = pro_moca(df_motifs_CLUMPs_path, 'h')
# Out:
# folder exists
# hydrophobicity classification scheme chosen
#
#  the following are the classes of AAs:
#  hydrophilic -> P
#  neutral -> N
#  hydrophobic -> B
#
#
#
#
#
# /\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
# ------------------------------------------
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\
#
#
#
# This is the alignment for CLUMP 0
#
#
#
# original lst_patterns ['NNBN', 'NNBNP', 'NBN', 'NBNP', 'BBN', 'BPN', 'BNNN', 'BPB', 'BNBB', 'BNB', 'PBB', 'BPN', 'BNPN', 'NBB']
#
#
#
#
#  -----------------
#  -----------------
#  letter_for_position B
#
#
#  lst_pos ['_', '_', '_', '_', 'B', 'B', 'B', 'B', 'B', 'B', '_', 'B', 'B', '_']
#
#  lst_indexes_letter_for_position [4, 5, 6, 7, 8, 9, 11, 12]
#
#
#
#  -----------------
#  letter_for_position N
#
#
#  lst_pos ['N', 'N', 'N', 'N', '_', '_', 'N', '_', 'N', 'N', '_', '_', 'N', 'N']
#
#  lst_indexes_letter_for_position [0, 1, 2, 3, 6, 8, 9, 12, 13]
#
#
#
#  -----------------
#  letter_for_position B
#
#
# ...

# %%
dict_alignments_all_lsts_motifs
# Out:
# {0: ['_GHWT_',
#   '_GHWTQ',
#   '_HWT__',
#   '_HWTQ_',
#   'WWS___',
#   'WNT___',
#   'YSHS__',
#   'CQY___',
#   'FSVF__',
#   'FSL___',
#   '_NVY__',
#   'WNS___',
#   'FTNS__',
#   '_HWF__'],
#  1: ['PGNV___',
#   '_PTHP__',
#   '_YPSG__',
#   'PYPGQ__',
#   'PYPSG__',
#   'GYPSG__',
#   '__RYPSG',
#   '__LYPSG',
#   '_PKPF__',
#   '_PTPK__',
#   '__YYPGG',
#   '_PKPY__',
#   '__VYPSG',
#   '_PSPK__',
#   'PYQSG__',
#   '_PKPN__',
#   '_PPPK__',
#   '__KPPG_',
#   '__RGIG_',
#   '_FPSP__',
#   '__KYPN_',
#   '__NGQP_'],
#  2: ['_PKPK',
#   '_PKYK',
#   '_WKPK',
#   'KHP__',
#   'KYKS_',
#   '_KQAQ',
#   'KTKL_',
#   '_PKAK',
#   '_QEAF',
#   '_HGD_',
#   '_AYKN',
#   'KMKG_',
#   '_FKAK',
#   '_IKNN',
#   '_KKIS',
#   '_MDKF',
#   '_VKSY'],
#  3: ['ADAE__',
#   '_CGEGE',
#   '_DAP__',
#   'ACGE__',
#   'ATEN__',
#   '_DQAG_',
#   '_KDLE_',
#   '_MGVE_',
#   '_QEKL_',
#   'SNEE__',
#   'AEG___',
#   'AEAD__',
#   'AETD__',
#   '_DENL_',
#   '_NEAK_',
#   '_NEPL_',
#   'TEAK__',
# ...

# %% [markdown]
# # charge alignment

# %%
dict_alignments_all_lsts_motifs = pro_moca(df_motifs_CLUMPs_path, 'cha')
# Out:
# folder exists
# charge classification scheme chosen
#
#  the following are the classes of AAs:
#  positive -> P
#  negative -> N
#  neutral -> U
#
#
#
#
#
# /\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
# ------------------------------------------
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\
#
#
#
# This is the alignment for CLUMP 0
#
#
#
# original lst_patterns ['UPUU', 'UPUUU', 'PUU', 'PUUU', 'UUU', 'UUU', 'UUPU', 'UUU', 'UUUU', 'UUU', 'UUU', 'UUU', 'UUUU', 'PUU']
#
#
#
#
#  -----------------
#  -----------------
#  letter_for_position U
#
#
#  lst_pos ['U', 'U', '_', '_', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', '_']
#
#  lst_indexes_letter_for_position [0, 1, 4, 5, 6, 7, 8, 9, 10, 11, 12]
#
#
#
#  -----------------
#  letter_for_position U
#
#
#  lst_pos ['_', '_', '_', '_', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', '_']
#
#  lst_indexes_letter_for_position [4, 5, 6, 7, 8, 9, 10, 11, 12]
#
#
#
#  -----------------
#  letter_for_position U
#
#
# ...

# %%
dict_alignments_all_lsts_motifs
# Out:
# {0: ['GHWT_',
#   'GHWTQ',
#   'HWT__',
#   'HWTQ_',
#   'WWS__',
#   'WNT__',
#   'YSHS_',
#   'CQY__',
#   'FSVF_',
#   'FSL__',
#   'NVY__',
#   'WNS__',
#   'FTNS_',
#   'HWF__'],
#  1: ['PGNV_',
#   'PTHP_',
#   'YPSG_',
#   'PYPGQ',
#   'PYPSG',
#   'GYPSG',
#   'RYPSG',
#   'LYPSG',
#   'PKPF_',
#   'PTPK_',
#   'YYPGG',
#   'PKPY_',
#   'VYPSG',
#   'PSPK_',
#   'PYQSG',
#   'PKPN_',
#   'PPPK_',
#   'KPPG_',
#   'RGIG_',
#   'FPSP_',
#   'KYPN_',
#   'NGQP_'],
#  2: ['PKPK_',
#   'PKYK_',
#   'WKPK_',
#   '_KHP_',
#   '_KYKS',
#   '_KQAQ',
#   '_KTKL',
#   'PKAK_',
#   'QEAF_',
#   '_HGD_',
#   'AYKN_',
#   '_KMKG',
#   'FKAK_',
#   'IKNN_',
#   '_KKIS',
#   'MDKF_',
#   'VKSY_'],
#  3: ['ADAE_',
#   'CGEGE',
#   'DAP__',
#   'ACGE_',
#   'ATEN_',
#   'DQAG_',
#   'KDLE_',
#   'MGVE_',
#   'QEKL_',
#   'SNEE_',
#   'AEG__',
#   'AEAD_',
#   'AETD_',
#   'DENL_',
#   'NEAK_',
#   'NEPL_',
#   'TEAK_',
#   'VDEG_'],
#  4: ['TQLA',
#   'NLVG',
#   'AYAR',
#   'DIAK',
# ...

# %% [markdown]
# # secondary structure propensity alignment

# %%
dict_alignments_all_lsts_motifs = pro_moca(df_motifs_CLUMPs_path, 'ssp')
# Out:
# folder exists
# secondary structure propensity classification scheme chosen
#
#  the following are the classes of AAs:
#  helix -> H
#  sheet -> S
#  turn -> T
#
#
#
#
#
# /\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
# ------------------------------------------
# \/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\
#
#
#
# This is the alignment for CLUMP 0
#
#
#
# original lst_patterns ['THSS', 'THSSH', 'HSS', 'HSSH', 'SST', 'STS', 'STHT', 'SHS', 'STSS', 'STH', 'TSS', 'STT', 'SSTT', 'HSS']
#
#
#
#
#  -----------------
#  -----------------
#  letter_for_position S
#
#
#  lst_pos ['_', '_', '_', '_', 'S', 'S', 'S', 'S', 'S', 'S', '_', 'S', 'S', '_']
#
#  lst_indexes_letter_for_position [4, 5, 6, 7, 8, 9, 11, 12]
#
#
#
#  -----------------
#  letter_for_position T
#
#
#  lst_pos ['T', 'T', '_', '_', '_', 'T', 'T', '_', 'T', 'T', 'T', 'T', '_', '_']
#
#  lst_indexes_letter_for_position [0, 1, 5, 6, 8, 9, 10, 11]
#
#
#
#  -----------------
#  letter_for_position H
#
#
# ...

# %%
dict_alignments_all_lsts_motifs
# Out:
# {0: ['GHWT_',
#   'GHWTQ',
#   'HWT__',
#   'HWTQ_',
#   'WWS__',
#   'WNT__',
#   'YSHS_',
#   'CQY__',
#   'FSVF_',
#   'FSL__',
#   'NVY__',
#   'WNS__',
#   'FTNS_',
#   'HWF__'],
#  1: ['_PGNV__',
#   'PTHP___',
#   '_YPSG__',
#   'PYPGQ__',
#   'PYPSG__',
#   'GYPSG__',
#   '__RYPSG',
#   '__LYPSG',
#   '_PKPF__',
#   'PTPK___',
#   '__YYPGG',
#   '_PKPY__',
#   '__VYPSG',
#   '_PSPK__',
#   'PYQSG__',
#   '_PKPN__',
#   '_PPPK__',
#   '__KPPG_',
#   '__RGIG_',
#   '_FPSP__',
#   '__KYPN_',
#   '_NGQP__'],
#  2: ['__PKPK',
#   '__PKYK',
#   '_WKPK_',
#   '_KHP__',
#   'KYKS__',
#   '_KQAQ_',
#   'KTKL__',
#   '__PKAK',
#   '_QEAF_',
#   '_HGD__',
#   'AYKN__',
#   '_KMKG_',
#   '_FKAK_',
#   '_IKNN_',
#   '_KKIS_',
#   '_MDKF_',
#   '_VKSY_'],
#  3: ['ADAE___',
#   '__CGEGE',
#   '_DAP___',
#   '_ACGE__',
#   '_ATEN__',
#   '_DQAG__',
#   'KDLE___',
#   'MGVE___',
#   '_QEKL__',
#   '_SNEE__',
#   '_AEG___',
#   '_AEAD__',
#   '_AETD__',
#   '_DENL__',
#   '_NEAK__',
# ...
